# %%
# Cargamos librerías para análisis de datos
import pandas as pd
import sys
sys.path.append('../')
from src import sp_eda as se
pd.set_option('display.max_columns', None) # Utilizamos este comando para visualizar todas las columnas cuando hacemos un muestreo
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('../data/bank-additional.csv')

# %%
df1.sample(5)
# Out:
#        Unnamed: 0   age          job   marital    education  default  housing  \
# 24291       24413  46.0       admin.  DIVORCED  high.school      NaN      1.0
# 10423       10520  36.0  blue-collar    SINGLE     basic.9y      0.0      0.0
# 35233       35377  29.0       admin.   MARRIED  high.school      0.0      1.0
# 27161       27305  56.0       admin.  DIVORCED  high.school      0.0      1.0
# 35021       35165  47.0     services  DIVORCED  high.school      0.0      1.0
#
#        loan    contact  duration  campaign  pdays  previous     poutcome  \
# 24291   0.0   cellular       168         1    999         0  NONEXISTENT
# 10423   0.0  telephone       145         1    999         0  NONEXISTENT
# 35233   0.0   cellular      1871         4    999         0  NONEXISTENT
# 27161   0.0   cellular       176         2    999         0  NONEXISTENT
# 35021   0.0   cellular        47         3    999         0  NONEXISTENT
#
# ...

# %%
print(f'Nuestro archivo "bank-additional" de datos presenta un total de {df1.shape[0]} filas y {df1.shape[1]} columnas')
# Out:
# Nuestro archivo "bank-additional" de datos presenta un total de 43000 filas y 24 columnas

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      43000 non-null  int64
#  1   age             37880 non-null  float64
#  2   job             42655 non-null  object
#  3   marital         42915 non-null  object
#  4   education       41193 non-null  object
#  5   default         34019 non-null  float64
#  6   housing         41974 non-null  float64
#  7   loan            41974 non-null  float64
#  8   contact         43000 non-null  object
#  9   duration        43000 non-null  int64
#  10  campaign        43000 non-null  int64
#  11  pdays           43000 non-null  int64
#  12  previous        43000 non-null  int64
#  13  poutcome        43000 non-null  object
#  14  emp.var.rate    43000 non-null  float64
#  15  cons.price.idx  42529 non-null  object
#  16  cons.conf.idx   43000 non-null  object
# ...

# %% [markdown]
# Calculamos los valores nulos

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0           0
# age               5120
# job                345
# marital             85
# education         1807
# default           8981
# housing           1026
# loan              1026
# contact              0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx     471
# cons.conf.idx        0
# euribor3m         9256
# nr.employed          0
# y                    0
# date               248
# latitude             0
# longitude            0
# id_                  0
# dtype: int64

# %%
df1.isnull().sum()/df1.shape[0]*100
# Out:
# Unnamed: 0         0.000000
# age               11.906977
# job                0.802326
# marital            0.197674
# education          4.202326
# default           20.886047
# housing            2.386047
# loan               2.386047
# contact            0.000000
# duration           0.000000
# campaign           0.000000
# pdays              0.000000
# previous           0.000000
# poutcome           0.000000
# emp.var.rate       0.000000
# cons.price.idx     1.095349
# cons.conf.idx      0.000000
# euribor3m         21.525581
# nr.employed        0.000000
# y                  0.000000
# date               0.576744
# latitude           0.000000
# longitude          0.000000
# id_                0.000000
# dtype: float64

# %% [markdown]
# Valores duplicados

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Columnas categóricas

# %%
df1.select_dtypes(include= 'object').columns
# Out:
# Index(['job', 'marital', 'education', 'contact', 'poutcome', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'date', 'id_'],
#       dtype='object')

# %%
for col in df1.select_dtypes(include= 'object').columns:

    print(col.upper())

    print(df1[col].value_counts())

    print('------')
# Out:
# JOB
# job
# admin.           10873
# blue-collar       9654
# technician        7026
# services          4162
# management        3050
# retired           1790
# entrepreneur      1522
# self-employed     1489
# housemaid         1123
# unemployed        1063
# student            903
# Name: count, dtype: int64
# ------
# MARITAL
# marital
# MARRIED     25999
# SINGLE      12105
# DIVORCED     4811
# Name: count, dtype: int64
# ------
# EDUCATION
# education
# university.degree      12722
# high.school             9925
# basic.9y                6309
# professional.course     5477
# basic.4y                4356
# basic.6y                2386
# illiterate                18
# Name: count, dtype: int64
# ------
# CONTACT
# contact
# cellular     27396
# telephone    15604
# Name: count, dtype: int64
# ------
# POUTCOME
# poutcome
# NONEXISTENT    37103
# FAILURE         4461
# SUCCESS         1436
# Name: count, dtype: int64
# ------
# CONS.PRICE.IDX
# cons.price.idx
# 93,994    7938
# ...

# %% [markdown]
# **Función EDA_preliminar**
#
# Definimos la función EDA preliminar para este primer conjunto de datos 'bank-additional'. Luego haremos la limpieza y transformación de los datos.

# %%
se.eda_preliminar(df1)
# Out:
#        Unnamed: 0   age          job  marital            education  default  \
# 4766         4863  26.0  blue-collar   SINGLE             basic.4y      0.0
# 3881         3978  35.0      student   SINGLE          high.school      0.0
# 10598       10695  47.0   technician  MARRIED  professional.course      0.0
# 31882       32026  26.0     services   SINGLE          high.school      0.0
# 8439         8536  25.0       admin.   SINGLE          high.school      0.0
#
#        housing  loan    contact  duration  campaign  pdays  previous  \
# 4766       1.0   1.0  telephone       196         1    999         0
# 3881       0.0   0.0  telephone       135         1    999         0
# 10598      1.0   0.0  telephone        59         6    999         0
# 31882      1.0   0.0   cellular       177         2    999         0
# 8439       1.0   1.0  telephone       109         1    999         0
#
#           poutcome  emp.var.rate cons.price.idx cons.conf.idx euribor3m  \
# ...
