# %%
# Cargamos librerías para análisis de datos
import pandas as pd
import sys
sys.path.append('../../../')
from src import sp_eda as se
pd.set_option('display.max_columns', None) # Utilizamos este comando para visualizar todas las columnas cuando hacemos un muestreo
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_bank = pd.read_csv('../../../data/bank-additional.csv')

# %%
df_bank.sample(5)
# Out:
#        Unnamed: 0   age          job   marital            education  default  \
# 21888       21985  39.0   technician   MARRIED  professional.course      NaN
# 34086       34230  29.0  blue-collar   MARRIED             basic.9y      0.0
# 16660       16757  47.0   technician  DIVORCED          high.school      0.0
# 16169       16266  37.0  blue-collar  DIVORCED  professional.course      0.0
# 42686       12172  37.0       admin.   MARRIED          high.school      0.0
#
#        housing  loan    contact  duration  campaign  pdays  previous  \
# 21888      1.0   0.0   cellular       132         1    999         0
# 34086      0.0   0.0   cellular       189         3    999         0
# 16660      0.0   0.0   cellular        42        24    999         0
# 16169      0.0   0.0   cellular       107         2    999         0
# 42686      0.0   0.0  telephone       305         1    999         0
#
#           poutcome  emp.var.rate cons.price.idx cons.conf.idx euribor3m  \
# ...

# %%
print(f'Nuestro archivo "bank-additional" de datos presenta un total de {df_bank.shape[0]} filas y {df_bank.shape[1]} columnas')
# Out:
# Nuestro archivo "bank-additional" de datos presenta un total de 43000 filas y 24 columnas

# %%
df_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      43000 non-null  int64
#  1   age             37880 non-null  float64
#  2   job             42655 non-null  object
#  3   marital         42915 non-null  object
#  4   education       41193 non-null  object
#  5   default         34019 non-null  float64
#  6   housing         41974 non-null  float64
#  7   loan            41974 non-null  float64
#  8   contact         43000 non-null  object
#  9   duration        43000 non-null  int64
#  10  campaign        43000 non-null  int64
#  11  pdays           43000 non-null  int64
#  12  previous        43000 non-null  int64
#  13  poutcome        43000 non-null  object
#  14  emp.var.rate    43000 non-null  float64
#  15  cons.price.idx  42529 non-null  object
#  16  cons.conf.idx   43000 non-null  object
# ...

# %% [markdown]
# Valores nulos

# %%
df_bank.isnull().sum()
# Out:
# Unnamed: 0           0
# age               5120
# job                345
# marital             85
# education         1807
# default           8981
# housing           1026
# loan              1026
# contact              0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx     471
# cons.conf.idx        0
# euribor3m         9256
# nr.employed          0
# y                    0
# date               248
# latitude             0
# longitude            0
# id_                  0
# dtype: int64

# %%
df_bank.isnull().sum()/df_bank.shape[0]*100
# Out:
# Unnamed: 0         0.000000
# age               11.906977
# job                0.802326
# marital            0.197674
# education          4.202326
# default           20.886047
# housing            2.386047
# loan               2.386047
# contact            0.000000
# duration           0.000000
# campaign           0.000000
# pdays              0.000000
# previous           0.000000
# poutcome           0.000000
# emp.var.rate       0.000000
# cons.price.idx     1.095349
# cons.conf.idx      0.000000
# euribor3m         21.525581
# nr.employed        0.000000
# y                  0.000000
# date               0.576744
# latitude           0.000000
# longitude          0.000000
# id_                0.000000
# dtype: float64

# %% [markdown]
# Valores duplicados

# %%
df_bank.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Columnas categóricas

# %%
df_bank.select_dtypes(include= 'object').columns
# Out:
# Index(['job', 'marital', 'education', 'contact', 'poutcome', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'date', 'id_'],
#       dtype='object')

# %% [markdown]
# En las columnas categóricas están incluidas las columnas 'cons.price.idx', 'cons.conf.idx', 'euribor3m' y 'nr.employed' que son tipo "float64", pero tienen una "," en lugar de "." y no los reconoce como este tipo. Lo trataremos más adelante.

# %%
for col in df_bank.select_dtypes(include= 'object').columns:

    print(col.upper())

    print(df_bank[col].value_counts())

    print('------')
# Out:
# JOB
# job
# admin.           10873
# blue-collar       9654
# technician        7026
# services          4162
# management        3050
# retired           1790
# entrepreneur      1522
# self-employed     1489
# housemaid         1123
# unemployed        1063
# student            903
# Name: count, dtype: int64
# ------
# MARITAL
# marital
# MARRIED     25999
# SINGLE      12105
# DIVORCED     4811
# Name: count, dtype: int64
# ------
# EDUCATION
# education
# university.degree      12722
# high.school             9925
# basic.9y                6309
# professional.course     5477
# basic.4y                4356
# basic.6y                2386
# illiterate                18
# Name: count, dtype: int64
# ------
# CONTACT
# contact
# cellular     27396
# telephone    15604
# Name: count, dtype: int64
# ------
# POUTCOME
# poutcome
# NONEXISTENT    37103
# FAILURE         4461
# SUCCESS         1436
# Name: count, dtype: int64
# ------
# CONS.PRICE.IDX
# cons.price.idx
# 93,994    7938
# ...

# %% [markdown]
# Estadísticos numéricos

# %%
display(df_bank.describe().T)
# Out:
#                 count          mean           std      min          25%  \
# Unnamed: 0    43000.0  20651.099047  11868.770913    0.000  10381.75000
# age           37880.0     39.977112     10.437957   17.000     32.00000
# default       34019.0      0.000088      0.009390    0.000      0.00000
# housing       41974.0      0.535998      0.498708    0.000      0.00000
# loan          41974.0      0.155620      0.362499    0.000      0.00000
# duration      43000.0    257.739279    258.666033    0.000    102.00000
# campaign      43000.0      2.567233      2.772294    1.000      1.00000
# pdays         43000.0    962.330953    187.260394    0.000    999.00000
# previous      43000.0      0.174023      0.497366    0.000      0.00000
# emp.var.rate  43000.0      0.077128      1.573898   -3.400     -1.80000
# latitude      43000.0     36.856697      7.225948   24.396     30.61475
# longitude     43000.0    -95.939067     16.752282 -124.997   -110.49425
#
# ...

# %% [markdown]
# **Función EDA_preliminar**
#
# He definido la función EDA preliminar para este primer conjunto de datos 'bank-additional' y la he extraído a un archivo soporte llamado "sp_eda". A continuación comprobamos que funciona correctamente. Luego haremos la limpieza y transformación de los datos.

# %%
se.eda_preliminar(df_bank)
# Out:
#        Unnamed: 0   age         job   marital            education  default  \
# 39962       40129  73.0     retired   MARRIED             basic.4y      0.0
# 16752       16849  56.0  technician   MARRIED  professional.course      0.0
# 9260         9357  43.0  technician    SINGLE             basic.9y      0.0
# 27244       27388  54.0      admin.  DIVORCED          high.school      0.0
# 20391       20488  38.0  technician    SINGLE          high.school      NaN
#
#        housing  loan    contact  duration  campaign  pdays  previous  \
# 39962      1.0   1.0  telephone       538         2    999         0
# 16752      1.0   0.0   cellular       224         1    999         0
# 9260       1.0   0.0  telephone       461         2    999         0
# 27244      0.0   0.0   cellular        13         6    999         0
# 20391      0.0   0.0   cellular       104         6    999         0
#
#           poutcome  emp.var.rate cons.price.idx cons.conf.idx euribor3m  \
# ...
