# %% [markdown]
# Limpieza dataset "customer_details"
#
# - Eliminar la columna "Unnamed" porque no aporta valor
# - Poner en minúscula el nombre de todas las columnas
# - Cambiar el nombre de la columna "NumWebVisitsMonth" por "num_web_visit_month" para que quede más claro.
# - Crear dos columnas con el mes y el año que el cliente se convirtió en cliente de la empresa

# %%
# Tratamiento de datos

import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np

# ----------

# Exploración de archivos
import sys
sys.path.append('../../../')

#----------

# Funciones personalizadas
from src import sp_cleaning as sc

# %% [markdown]
# Cargamos los datos y hacemos una copia

# %%
df_customer = pd.ExcelFile('../../../data/customer-details.xlsx')

# %%
df_customer.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_customer.info()
#
# AttributeError: 'ExcelFile' object has no attribute 'info'
